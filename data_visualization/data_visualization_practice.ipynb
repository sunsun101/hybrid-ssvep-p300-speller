# %%
import numpy as np
import mne


fname = "record\sunsun\sunsun0.fif"
raw = mne.io.read_raw_fif(fname)
# Out:
# Opening raw data file record\sunsun\sunsun0.fif...
#     Range : 0 ... 30371 =      0.000 ...   121.484 secs
# Ready.
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_20256\1373054007.py:6: RuntimeWarning: This filename (record\sunsun\sunsun0.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fname)

# %%
print(raw)
print(raw.info)
# Out:
# <Raw | sunsun0.fif, 17 x 30372 (121.5 s), ~31 kB, data not loaded>
# <Info | 10 non-empty values
#  bads: []
#  ch_names: Fz, C3, Cz, C4, Pz, PO7, Oz, PO8, F5, F7, F3, F1, F2, F4, F6, ...
#  chs: 16 EEG, 1 Stimulus
#  custom_ref_applied: False
#  dig: 19 items (3 Cardinal, 16 EEG)
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 17
#  projs: []
#  sfreq: 250.0 Hz
# >

# %%
raw.plot_psd(fmax=50)
raw.plot(duration=5, n_channels=30)
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# Using matplotlib as 2D backend.
# e:\Thesis\hybrid-ssvep-p300-speller\hybridspeller\lib\site-packages\mne\viz\utils.py:137: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
fig = raw.plot_sensors(show_names=True)

# %%
info = mne.io.read_info(fname)
print(info)
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: Fz, C3, Cz, C4, Pz, PO7, Oz, PO8, F5, F7, F3, F1, F2, F4, F6, ...
#  chs: 16 EEG, 1 Stimulus
#  custom_ref_applied: False
#  dig: 19 items (3 Cardinal, 16 EEG)
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 17
#  projs: []
#  sfreq: 250.0 Hz
# >

# %%
print(info.keys())
# Out:
# dict_keys(['file_id', 'events', 'hpi_results', 'hpi_meas', 'subject_info', 'device_info', 'helium_info', 'hpi_subsystem', 'proc_history', 'meas_id', 'experimenter', 'description', 'proj_id', 'proj_name', 'meas_date', 'utc_offset', 'sfreq', 'highpass', 'lowpass', 'line_freq', 'gantry_angle', 'chs', 'dev_head_t', 'ctf_head_t', 'dev_ctf_t', 'dig', 'bads', 'ch_names', 'nchan', 'projs', 'comps', 'acq_pars', 'acq_stim', 'custom_ref_applied', 'xplotter_layout', 'kit_system_id'])

# %%
print(info['ch_names'])
# Out:
# ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'PO7', 'Oz', 'PO8', 'F5', 'F7', 'F3', 'F1', 'F2', 'F4', 'F6', 'F8', 'STIM MARKERS']

# %%
print(info['device_info'])
# Out:
# None
