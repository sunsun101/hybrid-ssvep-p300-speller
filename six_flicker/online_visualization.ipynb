# %%
import mne
import pickle
from brainflow import BoardShim
from brainflow import BoardShim
from speller_config import *
from mne import create_info
import matplotlib.pyplot as plt
import numpy as np
from mne import time_frequency

# %% [markdown]
# ### Stacking same class epochs and plotting stft

# %%
from glob import glob
import os
import numpy as np
import mne

def read_data(fpath):
    raw = mne.io.read_raw_fif(fpath, preload=True)
    x = raw.get_data()[:8, 250:1250]
    return np.expand_dims(x, axis=0)

files = glob(r'E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\*.fif')
# files = glob(r'E:\Thesis\HybridSpeller\three_flicker\record\sunsun_20230421_night\*.fif')
# files = glob(r'E:\Thesis\HybridSpeller\three_flicker\record\anagha_20230421\*.fif')
# files = glob(r'E:\Thesis\HybridSpeller\three_flicker\record\wan_20230421\*.fif')
data = {'A': [], 'B': [], 'C': []}

for fpath in files:
    filename = os.path.basename(fpath)
    group = filename[1]
    x = read_data(fpath)
    if group in data:
        data[group].append(x)

X_A = np.concatenate(data['A'])
X_B = np.concatenate(data['B'])
X_C = np.concatenate(data['C'])

print(X_A.shape, X_B.shape, X_C.shape)
# Out:
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0B.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0C.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0D.fif...
#     Range : 0 ... 1754 =      0.000 ...     7.016 secs
# Ready.
# Reading 0 ... 1754  =      0.000 ...     7.016 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0E.fif...
#     Range : 0 ... 1757 =      0.000 ...     7.028 secs
# Ready.
# Reading 0 ... 1757  =      0.000 ...     7.028 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0F.fif...
#     Range : 0 ... 1756 =      0.000 ...     7.024 secs
# Ready.
# Reading 0 ... 1756  =      0.000 ...     7.024 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1B.fif...
#     Range : 0 ... 1750 =      0.000 ...     7.000 secs
# Ready.
# Reading 0 ... 1750  =      0.000 ...     7.000 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1C.fif...
#     Range : 0 ... 1753 =      0.000 ...     7.012 secs
# Ready.
# Reading 0 ... 1753  =      0.000 ...     7.012 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1D.fif...
#     Range : 0 ... 1760 =      0.000 ...     7.040 secs
# Ready.
# Reading 0 ... 1760  =      0.000 ...     7.040 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1E.fif...
#     Range : 0 ... 1753 =      0.000 ...     7.012 secs
# Ready.
# Reading 0 ... 1753  =      0.000 ...     7.012 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1F.fif...
#     Range : 0 ... 1747 =      0.000 ...     6.988 secs
# Ready.
# Reading 0 ... 1747  =      0.000 ...     6.988 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2B.fif...
#     Range : 0 ... 1749 =      0.000 ...     6.996 secs
# Ready.
# Reading 0 ... 1749  =      0.000 ...     6.996 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2C.fif...
#     Range : 0 ... 1751 =      0.000 ...     7.004 secs
# Ready.
# Reading 0 ... 1751  =      0.000 ...     7.004 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2D.fif...
#     Range : 0 ... 1750 =      0.000 ...     7.000 secs
# Ready.
# Reading 0 ... 1750  =      0.000 ...     7.000 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2E.fif...
#     Range : 0 ... 1747 =      0.000 ...     6.988 secs
# Ready.
# Reading 0 ... 1747  =      0.000 ...     6.988 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2F.fif...
#     Range : 0 ... 1750 =      0.000 ...     7.000 secs
# Ready.
# Reading 0 ... 1750  =      0.000 ...     7.000 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3B.fif...
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
#     Range : 0 ... 1753 =      0.000 ...     7.012 secs
# Ready.
# Reading 0 ... 1753  =      0.000 ...     7.012 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3C.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3D.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3E.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3F.fif...
#     Range : 0 ... 1749 =      0.000 ...     6.996 secs
# Ready.
# Reading 0 ... 1749  =      0.000 ...     6.996 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4A.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4B.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4C.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4D.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4E.fif...
#     Range : 0 ... 1754 =      0.000 ...     7.016 secs
# Ready.
# Reading 0 ... 1754  =      0.000 ...     7.016 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4F.fif...
#     Range : 0 ... 1749 =      0.000 ...     6.996 secs
# Ready.
# Reading 0 ... 1749  =      0.000 ...     6.996 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\vineet_20230426_6_target.fif...
#     Range : 0 ... 204183 =      0.000 ...   816.732 secs
# Ready.
# Reading 0 ... 204183  =      0.000 ...   816.732 secs...
# (5, 8, 1000) (5, 8, 1000) (5, 8, 1000)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\1245087995.py:7: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\vineet_20230426_6_target.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fpath, preload=True)

# %%
# stft_data = []
# for i in range(X_C.shape[0]):
#     stft = time_frequency.stft(X_C[i], wsize=252, verbose=False); 
#     stft_data.append(np.expand_dims(stft, axis=0))
# stft_data = np.concatenate(stft_data, axis=0)
# stft_data.shape

# %%
# ch_names = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'PO7', 'Oz', 'PO8', 'STIM MARKERS']

# for ch_idx in range(0,8):
#     X = stft_data
#     X = X[:20]
#     print(X.shape)
#     # X = abs(X)
#     X = X.mean(axis=0)
#     X = X[ch_idx]
#     X = X[:45,:]
#     print(X.shape)

#     c = plt.pcolormesh(np.arange(0,(X.shape[1]) //2,0.5), range(X.shape[0]), np.abs(X), cmap='plasma', vmax=4e-6)
#     plt.colorbar(c)
#     plt.title(f'STFT Magnitude {ch_names[ch_idx]} {ch_idx=}')
#     plt.ylabel('Frequency [Hz]')
#     plt.xlabel('Time [sec]')
#     plt.show()

# %% [markdown]
# ### Plotting stft for each epoch

# %%
# fname = r'E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0A.fif'

# raw =  mne.io.read_raw_fif(fname,  preload = True)
# raw.plot()
# data = raw.get_data()[:8,250:1250]
# new_raw = mne.io.RawArray(data,raw.info)
# new_raw.plot()

# %%
# stft_data = []
# data = np.expand_dims(data,axis=0)
# print(data.shape)
# for i in range(data.shape[0]):
#     stft = time_frequency.stft(data[i], wsize=252, verbose=False); 
#     stft_data.append(np.expand_dims(stft, axis=0))
# stft_data = np.concatenate(stft_data, axis=0)
# stft_data.shape

# %%
# for ch_idx in range(1,8):
#     stft = stft_data[0,ch_idx]
#     stft = stft[:30,:]
#     c = plt.pcolormesh(np.arange(0,(stft.shape[1]) //2,0.5), range(stft.shape[0]), np.abs(stft), cmap='plasma', vmax=10e-6)
#     plt.colorbar(c)
#     plt.title(f'STFT Magnitude {raw.ch_names[ch_idx]} {ch_idx=}')
#     plt.ylabel('Frequency [Hz]')
#     plt.xlabel('Time [sec]')
#     plt.show()

# %%
from numpy import ndarray
import numpy as np
from scipy.sparse import vstack, identity, spmatrix
from typing import Optional, cast, Union
from scipy.linalg import eigh
from scipy.sparse.linalg import eigsh
from scipy.stats import pearsonr
from sklearn.base import BaseEstimator, ClassifierMixin, TransformerMixin
from joblib import Parallel, delayed
from functools import partial



def _ged_wong(
    Z: ndarray,
    D: Optional[ndarray] = None,
    P: Optional[ndarray] = None,
    n_components=1,
    method="type1",
):
    if method != "type1" and method != "type2":
        raise ValueError("not supported method type")

    A = Z
    if D is not None:
        A = D.T @ A
    if P is not None:
        A = P.T @ A
    A = A.T @ A
    if method == "type1":
        B = Z
        if D is not None:
            B = D.T @ Z
        B = B.T @ B
        if isinstance(A, spmatrix) or isinstance(B, spmatrix):
            D, W = eigsh(A, k=n_components, M=B)
        else:
            D, W = eigh(A, B)
    elif method == "type2":
        if isinstance(A, spmatrix):
            D, W = eigsh(A, k=n_components)
        else:
            D, W = eigh(A)

    D_exist = cast(ndarray, D)
    ind = np.argsort(D_exist)[::-1]
    D_exist, W = D_exist[ind], W[:, ind]
    return D_exist[:n_components], W[:, :n_components]


def _trca_kernel(X: ndarray):
    """TRCA.
    X: (n_trials, n_channels, n_samples)
    """
    X = np.reshape(X, (-1, *X.shape[-2:]))
    M, C, N = X.shape
    n_components = C
    P = vstack([identity(N) for _ in range(M)])
    P = P @ P.T
    # P = abs(P @ P.T)
    Z = np.hstack(X).T  # type: ignore
    _, U = _ged_wong(Z, None, P, n_components=n_components)  # U for X
    return U


def _trca_feature(
    X: ndarray,
    templates: ndarray,
    Us: ndarray,
    n_components: int = 1,
    ensemble: bool = True,
):
    rhos = []
    if not ensemble:
        for Xk, U in zip(templates, Us):
            a = U[:, :n_components].T @ X
            b = U[:, :n_components].T @ Xk
            a = np.reshape(a, (-1))
            b = np.reshape(b, (-1))
            rhos.append(pearsonr(a, b)[0])
    else:
        U = Us[:, :, :n_components]
        U = np.concatenate(U, axis=-1)
        for Xk in templates:
            a = U.T @ X
            b = U.T @ Xk
            a = np.reshape(a, (-1))
            b = np.reshape(b, (-1))
            rhos.append(pearsonr(a, b)[0])
    return rhos


class TRCA(BaseEstimator, TransformerMixin, ClassifierMixin):
    def __init__(
        self, n_components: int = 1, ensemble: bool = True, n_jobs: Optional[int] = None
    ):
        self.n_components = n_components
        self.ensemble = ensemble
        self.n_jobs = n_jobs

    def fit(self, X: ndarray, y: ndarray, Yf: Optional[ndarray] = None):
        self.classes_ = np.unique(y)
        X = np.reshape(X, (-1, *X.shape[-2:]))
        X = X - np.mean(X, axis=-1, keepdims=True)
        self.templates_ = np.stack(
            [np.mean(X[y == label], axis=0) for label in self.classes_]
        )

        self.Us_ = np.stack([_trca_kernel(X[y == label]) for label in self.classes_])
        return self

    def transform(self, X: ndarray):
        X = np.reshape(X, (-1, *X.shape[-2:]))
        X = X - np.mean(X, axis=-1, keepdims=True)
        n_components = self.n_components
        templates = self.templates_
        Us = self.Us_
        ensemble = self.ensemble
        rhos = Parallel(n_jobs=self.n_jobs)(
            delayed(
                partial(
                    _trca_feature, Us=Us, n_components=n_components, ensemble=ensemble
                )
            )(a, templates)
            for a in X
        )
        rhos = np.stack(rhos)
        return rhos

    def predict(self, X: ndarray):
        feat = self.transform(X)
        labels = self.classes_[np.argmax(feat, axis=-1)]
        return labels


def generate_cca_references(
    freqs,
    srate,
    T,
    phases: Optional[Union[ndarray, int, float]] = None,
    n_harmonics: int = 1,
):
    if isinstance(freqs, int) or isinstance(freqs, float):
        freqs = [freqs]
    freqs = np.array(freqs)[:, np.newaxis]
    if phases is None:
        phases = 0
    if isinstance(phases, int) or isinstance(phases, float):
        phases = np.array([phases])
    phases = np.array(phases)[:, np.newaxis]
    t = np.linspace(0, T, int(T * srate))

    Yf = []
    for i in range(n_harmonics):
        Yf.append(
            np.stack(
                [
                    np.sin(2 * np.pi * (i + 1) * freqs * t + np.pi * phases),
                    np.cos(2 * np.pi * (i + 1) * freqs * t + np.pi * phases),
                ],
                axis=1,
            )
        )
    Yf = np.concatenate(Yf, axis=1)
    return Yf

# %% [markdown]
# ### Passing all epoch in loop to TRCA

# %%
from glob import glob
import os
files = glob(r'E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\*.fif')
picked_channels = ['PO7', 'Oz', 'PO8']
y = []
X = []
for fpath in files:
    _,filename = os.path.split(fpath)
    y.append(filename[1])

    raw =  mne.io.read_raw_fif(fpath,  preload = True)
    raw.pick_channels(picked_channels)
    x = raw.get_data()[:8,250:1250]
    X.append(np.expand_dims(x,axis=0))

y = np.array(y)
X = np.concatenate(X)

print(X.shape, y.shape)

# fname = r'E:\Thesis\HybridSpeller\three_flicker\record\sunsun_20230420\2C.fif'

# raw =  mne.io.read_raw_fif(fname,  preload = True)
# raw.plot()
# data = raw.get_data()[:8,250:1250]
# new_raw = mne.io.RawArray(data,raw.info)
# new_raw.plot()
# Out:
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0B.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0C.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0D.fif...
#     Range : 0 ... 1754 =      0.000 ...     7.016 secs
# Ready.
# Reading 0 ... 1754  =      0.000 ...     7.016 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0E.fif...
#     Range : 0 ... 1757 =      0.000 ...     7.028 secs
# Ready.
# Reading 0 ... 1757  =      0.000 ...     7.028 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0F.fif...
#     Range : 0 ... 1756 =      0.000 ...     7.024 secs
# Ready.
# Reading 0 ... 1756  =      0.000 ...     7.024 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1B.fif...
#     Range : 0 ... 1750 =      0.000 ...     7.000 secs
# Ready.
# Reading 0 ... 1750  =      0.000 ...     7.000 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1C.fif...
#     Range : 0 ... 1753 =      0.000 ...     7.012 secs
# Ready.
# Reading 0 ... 1753  =      0.000 ...     7.012 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1D.fif...
#     Range : 0 ... 1760 =      0.000 ...     7.040 secs
# Ready.
# Reading 0 ... 1760  =      0.000 ...     7.040 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1E.fif...
#     Range : 0 ... 1753 =      0.000 ...     7.012 secs
# Ready.
# Reading 0 ... 1753  =      0.000 ...     7.012 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1F.fif...
#     Range : 0 ... 1747 =      0.000 ...     6.988 secs
# Ready.
# Reading 0 ... 1747  =      0.000 ...     6.988 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\1F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2B.fif...
#     Range : 0 ... 1749 =      0.000 ...     6.996 secs
# Ready.
# Reading 0 ... 1749  =      0.000 ...     6.996 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2C.fif...
#     Range : 0 ... 1751 =      0.000 ...     7.004 secs
# Ready.
# Reading 0 ... 1751  =      0.000 ...     7.004 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2D.fif...
#     Range : 0 ... 1750 =      0.000 ...     7.000 secs
# Ready.
# Reading 0 ... 1750  =      0.000 ...     7.000 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2E.fif...
#     Range : 0 ... 1747 =      0.000 ...     6.988 secs
# Ready.
# Reading 0 ... 1747  =      0.000 ...     6.988 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2F.fif...
#     Range : 0 ... 1750 =      0.000 ...     7.000 secs
# Ready.
# Reading 0 ... 1750  =      0.000 ...     7.000 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3A.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3B.fif...
#     Range : 0 ... 1753 =      0.000 ...     7.012 secs
# Ready.
# Reading 0 ... 1753  =      0.000 ...     7.012 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3C.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3D.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3E.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3F.fif...
#     Range : 0 ... 1749 =      0.000 ...     6.996 secs
# Ready.
# Reading 0 ... 1749  =      0.000 ...     6.996 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4A.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4B.fif...
#     Range : 0 ... 1755 =      0.000 ...     7.020 secs
# Ready.
# Reading 0 ... 1755  =      0.000 ...     7.020 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4C.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4D.fif...
#     Range : 0 ... 1752 =      0.000 ...     7.008 secs
# Ready.
# Reading 0 ... 1752  =      0.000 ...     7.008 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4E.fif...
#     Range : 0 ... 1754 =      0.000 ...     7.016 secs
# Ready.
# Reading 0 ... 1754  =      0.000 ...     7.016 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4F.fif...
#     Range : 0 ... 1749 =      0.000 ...     6.996 secs
# Ready.
# Reading 0 ... 1749  =      0.000 ...     6.996 secs...
# Opening raw data file E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\vineet_20230426_6_target.fif...
#     Range : 0 ... 204183 =      0.000 ...   816.732 secs
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\2F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\3F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4A.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4B.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4C.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4D.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\4F.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# C:\Users\Sunsun\AppData\Local\Temp\ipykernel_13236\2342669791.py:11: RuntimeWarning: This filename (E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\vineet_20230426_6_target.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw =  mne.io.read_raw_fif(fpath,  preload = True)
# Ready.
# Reading 0 ... 204183  =      0.000 ...   816.732 secs...
# (31, 3, 1000) (31,)

# %%
print(X.shape, y.shape)
loaded_model = pickle.load(open(r"E:\Thesis\HybridSpeller\six_flicker\TRCA_model.sav", 'rb'))
# Out:
# (31, 3, 1000) (31,)

# %%
preds = loaded_model.predict(X)

# %%
print(preds)
print(y)
# Out:
# [1 2 3 6 5 1 1 5 3 2 6 5 1 3 4 3 6 1 1 2 5 4 2 1 1 2 4 1 5 4 6]
# ['A' 'B' 'C' 'D' 'E' 'F' 'A' 'B' 'C' 'D' 'E' 'F' 'A' 'B' 'C' 'D' 'E' 'F'
#  'A' 'B' 'C' 'D' 'E' 'F' 'A' 'B' 'C' 'D' 'E' 'F' 'i']

# %%
c = 0
for idx in range(len(preds)):
    pred = preds[idx]
    label = y[idx]
    if(pred == 1):
        pred = 'A'
    if(pred == 2):
        pred = 'B'
    if(pred == 3):
        pred = 'C'
    if(pred == 4):
        pred = 'D'
    if(pred == 5):
        pred = 'E'
    if(pred == 6):
        pred = 'F'
    if(label == pred):
        c += 1

acc = c/30
print(acc)
# Out:
# 0.43333333333333335

# %% [markdown]
# ### Passing each pickle file into TRCA

# %%
from glob import glob
import os
from scipy import signal

pickle_files = glob(r'E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\*.pickle')

y_pickle = []
X_pickle = []
for fpath in pickle_files:
    _,filename = os.path.split(fpath)
    y_pickle.append(filename[1])

    with open(fpath, 'rb') as handle:
        pickle_data = pickle.load(handle)

    marker_channel = BoardShim.get_marker_channel(BOARD_ID)
    eeg_channels = BoardShim.get_eeg_channels(BOARD_ID)
    pickle_data[eeg_channels] = pickle_data[eeg_channels] / 1e6
    pickle_data = pickle_data[eeg_channels + [marker_channel]]

    _CHANNELS = ['FZ', 'C3', 'CZ', 'C4', 'PZ', 'PO7', 'OZ', 'PO8']
    # data = pickle_data[:8,:1740] # pickle-sunsun_20230420_night
    data = pickle_data[5:8,:1740]
    # data = pickle_data[:8,:1450]
    print(data.shape)
    
    order = 1
    l_freq = 4
    sos = signal.butter(order, l_freq, 'highpass', analog=False, fs=250, output='sos')
    notch_freq = 50
    quality = 1
    b,a = signal.iirnotch(notch_freq, quality, fs=250)
    for i in range(3):
        data[i] = signal.lfilter(b, a, data[i])
        data[i] = signal.sosfilt(sos, data[i])
    X_pickle.append(np.expand_dims(data[:],axis=0))
    # ch_names = [ch_name.upper() for ch_name in _CHANNELS]
    # ch_names = ch_names + ['STIM']
    # ch_types = ["eeg"] * 9
    # ch_types[-1] = "stim"

    # info = create_info(ch_names=ch_names, ch_types=ch_types, sfreq=250)
    # raw_pickle = mne.io.RawArray(pickle_data, info=info)
    # raw_pickle.notch_filter([50])
    # raw_pickle.filter(4,77)
    # x = raw_pickle.get_data()[:8,250:1250]
    # X_pickle.append(np.expand_dims(x,axis=0))

y_pickle = np.array(y_pickle)
X_pickle = np.concatenate(X_pickle)

print(X_pickle.shape, y_pickle.shape)
# Out:
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (3, 1740)
# (30, 3, 1740) (30,)

# %%
# X_A = X_pickle[y_pickle=='A']
# X_B = X_pickle[y_pickle=='B']
# X_C = X_pickle[y_pickle=='C']
# X_A.shape, X_B.shape, X_C.shape

# %%
# stft_data = []
# for i in range(X_A.shape[0]):
#     stft = time_frequency.stft(X_A[i], wsize=252, verbose=False); 
#     stft_data.append(np.expand_dims(stft, axis=0))
# stft_data = np.concatenate(stft_data, axis=0)
# stft_data.shape

# %%
# plt.plot(X_A[0,0,])
# plt.show()

# %%
# for ch_idx in range(1,8):
#     X = stft_data
#     # X = abs(X)
#     X = X.mean(axis=0)
#     print(X.shape)
#     X = X[ch_idx]
#     X = X[:45,:]
#     # X[0,:] = 0
#     # X[1,:] = 0
#     # X[2,:] = 0
#     # X[3,:] = 0
#     # X[4,:] = 0
#     # X[5,:] = 0
#     # X[:,0] = 0
#     # X[:,-1] = 0
#     print(X.shape)

#     c = plt.pcolormesh(np.arange(0,(X.shape[1]) //2,0.5), range(X.shape[0]), np.abs(X), cmap='plasma', vmax=4e-6)
#     plt.colorbar(c)
#     plt.title(f'STFT Magnitude {raw.ch_names[ch_idx]} {ch_idx=} From Online Pickle')
#     plt.ylabel('Frequency [Hz]')
#     plt.xlabel('Time [sec]')
#     plt.show()

# %%
offset = int(250 * 1.5)
preds_pickle = loaded_model.predict(X_pickle[:,:,offset:offset + 1000])
# print(preds_pickle)
# print(y_pickle)
c = 0
for idx in range(len(preds_pickle)):
    pred = preds_pickle[idx]
    label = y_pickle[idx]
    if(pred == 1):
        pred = 'A'
    if(pred == 2):
        pred = 'B'
    if(pred == 3):
        pred = 'C'
    if(pred == 4):
        pred = 'D'
    if(pred == 5):
        pred = 'E'
    if(pred == 6):
        pred = 'F'
    if(label == pred):
        c += 1
    print(idx, f"{pred=} {label=}" )
print(c/30)
# Out:
# 0 pred='A' label='A'
# 1 pred='D' label='B'
# 2 pred='C' label='C'
# 3 pred='A' label='D'
# 4 pred='E' label='E'
# 5 pred='F' label='F'
# 6 pred='A' label='A'
# 7 pred='F' label='B'
# 8 pred='C' label='C'
# 9 pred='C' label='D'
# 10 pred='E' label='E'
# 11 pred='F' label='F'
# 12 pred='A' label='A'
# 13 pred='A' label='B'
# 14 pred='B' label='C'
# 15 pred='D' label='D'
# 16 pred='B' label='E'
# 17 pred='F' label='F'
# 18 pred='A' label='A'
# 19 pred='A' label='B'
# 20 pred='D' label='C'
# 21 pred='A' label='D'
# 22 pred='D' label='E'
# 23 pred='A' label='F'
# 24 pred='A' label='A'
# 25 pred='D' label='B'
# 26 pred='C' label='C'
# 27 pred='A' label='D'
# 28 pred='C' label='E'
# 29 pred='C' label='F'
# 0.4666666666666667

# %% [markdown]
# ### Passing one pickle file into TRCA

# %%
# pickle_filename = r'E:\Thesis\HybridSpeller\six_flicker\record\vineet_20230426_6_target\0B.pickle'

# with open(pickle_filename, 'rb') as handle:
#     pickle_data = pickle.load(handle)

# %%
# marker_channel = BoardShim.get_marker_channel(BOARD_ID)
# eeg_channels = BoardShim.get_eeg_channels(BOARD_ID)
# pickle_data[eeg_channels] = pickle_data[eeg_channels] / 1e6
# pickle_data = pickle_data[eeg_channels + [marker_channel]]

# for i in range(9):
#     plt.plot(pickle_data[i,-500:])
#     plt.show()

# %%
# _CHANNELS = ['FZ', 'C3', 'CZ', 'C4', 'PZ', 'PO7', 'OZ', 'PO8']
# ch_names = [ch_name.upper() for ch_name in _CHANNELS]
# ch_names = ch_names + ['STIM']
# ch_types = ["eeg"] * 9
# ch_types[-1] = "stim"

# info = create_info(ch_names=ch_names, ch_types=ch_types, sfreq=250)

# %%
# raw_pickle = mne.io.RawArray(pickle_data, info=info)
# raw_pickle.notch_filter([50])
# raw_pickle.filter(4,77)
# raw_pickle.plot()

# %%
# data = raw_pickle.get_data()[:8,250:1250]

# %%
# pred = loaded_model.predict(data)
# print(pred)
